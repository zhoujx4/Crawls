# %%
from selenium import webdriver
from lxml import etree
import time
import re
from selenium.webdriver.chrome.options import Options

# %% [markdown]
# 				# 广州
# 				# "https://land.3fang.com/market/440100__1______1_1_1.html", # 住宅用地: 26页
# 				# "https://land.3fang.com/market/440100__2______1_1_1.html", # 商业/办公用地: 17页
# 				# "https://land.3fang.com/market/440100__3_2__0_100000__1_1_1.html", # 工业用地, 已成交, 10万平米以下: 32页
# 				# "https://land.3fang.com/market/440100__3_2__100000_500000__1_1_1.html",  # 工业用地, 已成交, 10-50万平米: 4页
# 				# "https://land.3fang.com/market/440100__3_2__500000_100000000__1_1_1.html", # 工业用地, 已成交, 50万平米以上: 1页
# 				# "https://land.3fang.com/market/440100__3_1_____1_1_1.html", # 工业用地, 未成交: 1页
# 				# "https://land.3fang.com/market/440100__3_3_____1_1_1.html", # 工业用地, 流拍: 7页
# 				# "https://land.3fang.com/market/440100__4______1_1_1.html", # 其他用地: 4页
# 				# # 佛山
# 				"https://land.3fang.com/market/440600__1_1_____1_1_1.html", # 住宅用地, 未成交: 8页
# 				"https://land.3fang.com/market/440600__1_2__0_5000__1_1_1.html", # 住宅用地, 已成交, 5千平米以下: 33页
# 				"https://land.3fang.com/market/440600__1_2__5000_100000__1_1_1.html", # 住宅用地, 已成交, 5千到10万平米: 29页
# 				"https://land.3fang.com/market/440600__1_2__100000_100000000__1_1_1.html", # 住宅用地, 已成交, 10万平米以上: 6页
# 				"https://land.3fang.com/market/440600__1_3_____1_1_1.html", # 住宅用地, 流拍: 3页
# 				"https://land.3fang.com/market/440600__2______1_1_1.html", # 商业用地: 19页
# 				"https://land.3fang.com/market/440600__3_1_____1_1_1.html", # 工业用地, 未成交: 6页
# 				"https://land.3fang.com/market/440600__3_2__0_40000__1_1_1.html", # 工业用地, 已成交, 4万平米以下: 32页
# 				"https://land.3fang.com/market/440600__3_2__40000_100000000__1_1_1.html", # 工业用地, 已成交, 4万平米以上: 12页
# 				"https://land.3fang.com/market/440600__3_3_____1_1_1.html", # 工业用地, 流拍: 1页
# 				"https://land.3fang.com/market/440600__4______1_1_1.html", # 其他用地: 3页

# %% [markdown]
# # 登录

# %%
# chromedriver的绝对路径
driver_path = r'D:\chromedriver.exe'
# 初始化一个driver，并且指定chromedriver的路径
driver = webdriver.Chrome(executable_path=driver_path)


#设置无头 
# chrome_options = Options()
# chrome_options.add_argument('--headless')
# driver = webdriver.Chrome(executable_path=driver_path, options=chrome_options)



# 请求网页
driver.get("http://passport.3fang.com/")
# 通过page_source获取网页源代码
# print(driver.page_source)

# %%
inputTag = driver.find_element_by_id('tel')
inputTag.send_keys('15625122214')

sendTag = driver.find_element_by_id('send')
sendTag.click()

code = input("输入验证码")
# Out:
# 输入验证码1742

# %%
inputTag = driver.find_element_by_id('phoneVerify')
inputTag.send_keys(code)


loginTag = driver.find_element_by_id('login')
loginTag.click()

# %% [markdown]
# # 账号密码登录

# %%
# chromedriver的绝对路径
driver_path = r'D:\chromedriver.exe'
# 初始化一个driver，并且指定chromedriver的路径
driver = webdriver.Chrome(executable_path=driver_path)


#设置无头 
# chrome_options = Options()
# chrome_options.add_argument('--headless')
# driver = webdriver.Chrome(executable_path=driver_path, options=chrome_options)



# 请求网页
driver.get("https://gz.zu.fang.com/house-a080/")
# 通过page_source获取网页源代码
# print(driver.page_source)

# inputTag = driver.find_element_by_id('username')
# inputTag.send_keys("15625122214")

inputTag = driver.find_element_by_id('password')
inputTag.send_keys("2012051171id")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fd3bf610680e> in <module>
#       2 driver_path = r'D:\chromedriver.exe'
#       3 # 初始化一个driver，并且指定chromedriver的路径
# ----> 4 driver = webdriver.Chrome(executable_path=driver_path)
#       5
#       6
#
# NameError: name 'webdriver' is not defined

# %% [markdown]
# # 跳转到索引页

# %%
driver.switch_to.window(driver.window_handles[0])
driver.execute_script("window.open('https://land.3fang.com/market/440600__1_1_____1_1_1.html')")
driver.switch_to.window(driver.window_handles[1])

# %% [markdown]
# # 主程序

# %%
Infos = []
wrong = []

source = driver.page_source
#得到所有索引页的列表
page_list = get_page_list(source)
print(page_list)

driver.close()
driver.switch_to.window(driver.window_handles[0])

for each_page in page_list:
    print("正在爬取", each_page)
    driver.execute_script("window.open(\'{}\')".format(each_page))
    driver.switch_to.window(driver.window_handles[1])
    
    #得到所有详情页的点击Selector
    submitTag1 = driver.find_elements_by_xpath("//h3/a") 
    for each_detial in submitTag1:
        each_detial.click()
        driver.switch_to.window(driver.window_handles[-1])
        source = driver.page_source
        current_url = driver.current_url
        print(current_url)
        print(source)
#         try:
#             Info = parse_details(source)
#         except:
#             print('有问题的网站')
#             wrong.append(current_url)
        
        Info = parse_details(source)
            
        Info['网址'] = current_url
        Infos.append(Info)
        driver.close()
        driver.switch_to.window(driver.window_handles[1])
        #解析
        time.sleep(0.2)
        
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
# Out:
# ['https://land.3fang.com/market/440600__1_1_____1_1_1.html', 'https://land.3fang.com/market/440600__1_1_____1_1_2.html', 'https://land.3fang.com/market/440600__1_1_____1_1_3.html', 'https://land.3fang.com/market/440600__1_1_____1_1_4.html', 'https://land.3fang.com/market/440600__1_1_____1_1_5.html', 'https://land.3fang.com/market/440600__1_1_____1_1_6.html', 'https://land.3fang.com/market/440600__1_1_____1_1_7.html', 'https://land.3fang.com/market/440600__1_1_____1_1_8.html']
# 正在爬取 https://land.3fang.com/market/440600__1_1_____1_1_1.html
# https://land.3fang.com/market/86341a07-b078-4b99-9316-bdb2b8f066ce.html
# <html xmlns="http://www.w3.org/1999/xhtml"><head><script type="text/javascript" src="//js.soufunimg.com/industry/land/js/headMarketSearch.js?v=20151201"></script>
# <meta http-equiv="Content-Type" content="text/html; charset=gb2312">
# <meta http-equiv="Cache-Control" content="no-transform">
# <meta name="mobile-agent" content="format=html5;url=http://m.3fang.com/tudi/zpgdetail/86341a07-b078-4b99-9316-bdb2b8f066ce.html">
# <link rel="alternate" media="only screen and(max-width: 640px)" href="http://m.3fang.com/tudi/zpgdetail/86341a07-b078-4b99-9316-bdb2b8f066ce.html">
# <title>佛山市禅城区佛山一环东侧、南庄大道北侧地块_广东佛山禅城土地招拍挂-3房网土地网</title>
# <meta name="keywords" content="广东佛山禅城土地招拍挂">
# <meta name="description" content="佛山市禅城区佛山一环东侧、南庄大道北侧地块土地招拍挂详细信息：所在地广东佛山禅城，佛山市禅城区佛山一环东侧、南庄大道北侧地块，A地块：二类居住用地，兼容商业商务用地，B地块：商业商务用地，兼容二类居住用地，规划建筑面积105850，住宅用地70年，商服用地40年出让年限。">
# <script src="https://zz.bdstatic.com/linksubmit/push.js"></script><script type="text/javascript" async="" src="//static.soufunimg.com/ggcp/3fang/load.min.js?v=20181220"></script><script src="//static.soufunimg.com/common_m/pc_public/fangjs/build/ie8/ie8.3.js" type="text/javascript"></script>
# <!--最早切页面-->
# <script src="//js.soufunimg.com/industry/commonjs/jquery-1.4.2.min.js?v=2013" type="text/javascript"></script>
# <script src="//js.soufunimg.com/industry/land/js/UserCookie.js?v=20170419" type="text/javascript"></script>
# <script type="text/javascript" src="//jsub.3fang.com/3fang/_ub.js?v=201807181100"></script>
# <link href="//js.soufunimg.com/industry/land/css/base.css?v=20140117.1.1" rel="stylesheet" type="text/css">
# <link href="//js.soufunimg.com/industry/land/css/base.css?v=20180905" rel="stylesheet" type="text/css">
# <!--<link href="/css/base.css?v=20141020" rel="stylesheet"  type="text/css" />-->
#
#   <!--<script>
# var _hmt = _hmt || [];
# (function() {
# var hm = document.createElement("script");
# hm.src = "//hm.baidu.com/hm.js?9e45c915a52098cc2e351c0e70fe1900";
# var s = document.getElementsByTagName("script")[0];
# s.parentNode.insertBefore(hm, s);
# })();
# </script> -->
#
# <script type="text/javascript">
#      var _dctc = _dctc || {};
#         _dctc.bid = 1;
#         _dctc.isNorth = _dctc.isNorth || 'Y';
#     (function() {
#         var script = document.createElement('script'); script.type = 'text/javascript'; script.async = true;script.src = '//static.soufunimg.com/ggcp/3fang/load.min.js?v=20181220';
#         var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(script, s);
#     })();
# </script>
#
# <script src="//js.soufunimg.com/industry/commonjs/blockUI.js?v=1.1" type="text/javascript"></script>
# <link href="//js.soufunimg.com/industry/land/css/main_1210.css?v=201409" rel="stylesheet" type="text/css">
#
#
# <script>
# (function(){
#     var bp = document.createElement('script');
#     var curProtocol = window.location.protocol.split(':')[0];
#     if (curProtocol === 'https'){
#    bp.src = 'https://zz.bdstatic.com/linksubmit/push.js';
#   }
#   else{
#   bp.src = 'http://push.zhanzhang.baidu.com/push.js';
#   }
#     var s = document.getElementsByTagName("script")[0];
#     s.parentNode.insertBefore(bp, s);
# })();
# </script>
# <script>(function(){
# var src = (document.location.protocol == "http:") ? "http://js.passport.qihucdn.com/11.0.1.js?56e08f8bc02dd828da7ee68c88631235":"https://jspassport.ssl.qhimg.com/11.0.1.js?56e08f8bc02dd828da7ee68c88631235";
# document.write('<script src="' + src + '" id="sozz"><\/script>');
# })();
# </script><script src="https://jspassport.ssl.qhimg.com/11.0.1.js?56e08f8bc02dd828da7ee68c88631235" id="sozz"></script><script charset="utf-8" src="https://s.ssl.qhres.com/ssl/ab77b6ea7f3fbf79.js"></script>
# </head>
#
# <body style="" quick-markup_injected="true"><div id="SFmenu" style="position: absolute; z-index: 100;"></div>
#
# <div id="divHeaderTop">
#     <!--https://www.fang.com/nav/sFang/land/bj.do-->
#
#
# <link rel="dns-prefetch" href="//jsub.fang.com">
# <link rel="dns-prefetch" href="//clickm.fang.com">
# <link rel="dns-prefetch" href="//countubn.3g.fang.com">
# <link rel="dns-prefetch" href="//countpvn.3g.fang.com">
# <link rel="dns-prefetch" href="//static.soufunimg.com">
# <link rel="dns-prefetch" href="//img.soufunimg.com">
# <link rel="dns-prefetch" href="//imgs.soufunimg.com">
# <link rel="dns-prefetch" href="//img1.soufunimg.com">
# <link rel="dns-prefetch" href="//img1n.soufunimg.com">
# <link rel="dns-prefetch" href="//imgd.soufunimg.com">
# <link rel="dns-prefetch" href="//imgdn.soufunimg.com">
# <link rel="dns-prefetch" href="//img2.soufunimg.com">
# <link rel="dns-prefetch" href="//img2s.soufunimg.com">
# <link rel="dns-prefetch" href="//flvn.soufunimg.com">
# <link rel="dns-prefetch" href="//flvs.soufunimg.com">
# <link rel="dns-prefetch" href="//video2n.soufunimg.com">
# <link rel="dns-prefetch" href="//video2s.soufunimg.com">
# <link rel="dns-prefetch" href="//ssl.google-analytics.com">
# <link rel="dns-prefetch" href="//cdnsfb.soufunimg.com">
# <link rel="dns-prefetch" href="//img11.soufunimg.com">
# <link href="//static.soufunimg.com/homepage/navigation/sfang/style/Topnav.css?v=1229" rel="stylesheet" type="text/css">
# <!-- <link href="/css/sFang/style/Topnav.css" rel="stylesheet" type="text/css" /> -->
#
# <div class="newnav20141104">
# 	<div class="newnav20141104nr clearfix">
#     	<div class="s1"><a href="http://www1.3fang.com/"><img src="//static.soufunimg.com/homepage/navigation/sfang/images/logo_3fang.png" alt=""></a></div>
# 		<ul>
#
# 				<li track-id="www1"><a href="http://bj.3fang.com">首页</a></li>
#
#           <li class="drop" onmouseover="this.className='drop on'" onmouseout="this.className='drop'">
#           <a href="https://shop.3fang.com/bj">商铺租售</a>
# 			<div class="listBox">
#             	<dl>
#                    	<dd><a href="https://shop.3fang.com/bj/zu/house/">商铺出租</a></dd>
#                    	<dd><a href="https://shop.3fang.com/bj">商铺出售</a></dd>
#                 </dl>
#
#             </div>
#         </li>
#           <li><a href="https://shop.3fang.com/bj/list/xinpan ">商铺楼盘</a></li>
#           <li class="drop" onmouseover="this.className='drop on'" onmouseout="this.className='drop'">
#           <a href="https://office.3fang.com/bj">写字楼租售</a>
# 			<div class="listBox">
#             	<dl>
#                    	<dd><a href="https://office.3fang.com/bj">写字楼出租</a></dd>
#                    	<dd><a href="https://office.3fang.com/bj/shou/house/">写字楼出售</a></dd>
#                 </dl>
#
#             </div>
#         </li>
#           <li><a href="https://office.3fang.com/bj/list/xinpan/ ">写字楼楼盘</a></li>
#           <li><a href="https://apartment.3fang.com/bj  ">品牌公寓</a></li>
#        	  <li><a href="http://wuye.3fang.com/ ">物业</a></li>
#           <li style="color: rgb(255, 255, 255); background: rgb(179, 0, 0); box-shadow: rgba(0, 0, 0, 0.1) 0px 0px 20px inset;"><a href="http://land.3fang.com/ ">土地</a></li>
#           <li track-id="news"><a href="https://news.3fang.com/bj">百科</a></li>
#         </ul>
#
#         <div class="rsign no2" onmouseover="this.className='rsign on'" onmouseout="this.className='rsign'" style="background-image:none;padding:0 5px;"><a href="http://d.3fang.com/">土地云</a></div>
#         <div class="rsign no2" onmouseover="this.className='rsign on'" onmouseout="this.className='rsign'" style="background-image:none;padding:0 5px;"><a href="http://s.3fang.com/">商办云</a></div>
#         <div class="rsign" onmouseover="this.className='rsign on'" onmouseout="this.className='rsign'" style="width:70px;" id="loginBarNew"><a href="javascript:void(0);" onmouseover="changeLoginUrl();" onclick="changeLoginUrl();" id="sfHeadUsername">3fang6028335609</a><input type="hidden" id="userCenterUrl" value="http://my.3fang.com/"><div class="listBox"><ul><li><a href="http://my.3fang.com/" target="_blank">我的3Fang</a></li><li><a href="/User/LoginOut.aspx" target="_self" class="tuic">退出</a></li></ul></div></div>
#
# 	</div>
# </div>
#
# <script type="text/javascript" src="//static.soufunimg.com/navigation/newnav20141111.js"></script>
#
# <!-- login js start -->
# <script type="text/javascript" src="//static.soufunimg.com/homepage/new/family/js/loginSFangUnited.js?v=201900204" charset="GBK"></script>
# <!-- <script type="text/javascript" src="/js/loginSFangUnited.js?v=107" charset="GBK"></script> -->
# <!-- login js end -->
# <!-- 新导航0903 end  -->
# </div><img src="https://countpv3g.3fang.com/countpv?v=1.33^b=1^f=0^l=https://land.3fang.com/market/86341a07-b078-4b99-9316-bdb2b8f066ce.html^r=https://land.3fang.com/market/440600__1_1_____1_1_1.html^g=blkwstz526uzkp98mjsvpdfvq2bjz0nr8i8^u=U_blkwstz526uzkp98mjsvpdfvq2bjz0nr8i8^c=1^a=0^s=nnn/hwwnn^m=21^t=%E4%BD%9B%E5%B1%B1%E5%B8%82%E7%A6%85%E5%9F%8E%E5%8C%BA%E4%BD%9B%E5%B1%B1%E4%B8%80%E7%8E%AF%E4%B8%9C%E4%BE%A7%E3%80%81%E5%8D%97%E5%BA%84%E5%A4%A7%E9%81%93%E5%8C%97%E4%BE%A7%E5%9C%B0%E5%9D%97_%E5%B9%BF%E4%B8%9C%E4%BD%9B%E5%B1%B1%E7%A6%85%E5%9F%8E%E5%9C%9F%E5%9C%B0%E6%8B%9B%E6%8B%8D%E6%8C%82-3%E6%88%BF%E7%BD%91%E5%9C%9F%E5%9C%B0%E7%BD%91^i=1~E371F73B865701AB38211DDB5333C5B147F707E97DB6981F2B9B3AF497A0F26551B4F447791FCEECDF7F4444219185FC925B18EBD247BA950DF7FC5AB356B4687BC5E197F9EE19FCD569DB8E9C63D6D6E3392FA286D8472619B5984B794DFFC9^1565147523640^o=^realip=^pageid=" width="0" height="0">
# <script type="text/javascript" language="javascript">
#     var username = "";
#     function SetTop() {
#
#         $.ajax({
#             dataType: 'json',
#             url: '/ajax/user.ashx',
#             //async: false,
#             data: { mode: '100', rd: Math.random() * 99999 },
#              success: function(json) {
#                 if (json.username != ""){
#                     username = json.username;
#                 }
#                 setUserInfo();
#             }, error: function() {
#                 setUserInfo();
#             }
#
#         });
#     };
#
#     //var username=cookieUserName;
#     //alert(username);
#     function setUserInfo() {
#         var obj = document.getElementById('loginBarNew');
#         if (obj) {
#             var str = '';
#             if (username != "") {
#                     str='<a href="javascript:void(0);" onmouseover="changeLoginUrl();" onclick="changeLoginUrl();" id="sfHeadUsername">' + username + '</a>'
#                     +'<input type="hidden" id="userCenterUrl" value="http://my.3fang.com/" />'
# 			        +'<div class="listBox">'
#             	    +'<ul>'
#                    	+'<li><a href="http://my.3fang.com/" target="_blank">我的3Fang</a></li>'
#                    	+'<li><a href="/User/LoginOut.aspx" target="_self" class="tuic">退出</a></li>'
#                     +'</ul>'
#                     +'</div>';
#                  obj.innerHTML = str;
#             }
#
#         }
#     }
#     SetTop();
# </script>
# <link href="//js.soufunimg.com/industry/land/css/fang_css_soufunsearch140717.css?v=20141020" rel="stylesheet" type="text/css">
#
#
#
# <script type="text/javascript" src="//js.soufunimg.com/industry/fdc/js/gb2312decode.js?v=20111201"></script>
# <script type="text/javascript" src="//js.soufunimg.com/industry/land/js/SearchBase.js?v=201407"></script>
# <script type="text/javascript" language="javascript">
#     SetNote("divUser");
#
#     var MarketSearchUrl = '/market/#city#_#dis#_#usage#_#status#____#keyword#_1_0_1.html';
#     function loadScript(B, D) { var A = document.createElement("script"), C = document.documentElement.firstChild; A.type = "text/javascript"; if (A.readyState) { A.onreadystatechange = function() { if (A.readyState == "loaded" || A.readyState == "complete") { A.onreadystatechange = null; D() } } } else { A.onload = function() { D() } } A.src = B; C.insertBefore(A, C.firstChild) };
#     loadScript("//js.soufunimg.com/industry/land/js/headMarketSearch.js?v=20151201", function() { setTimeout(function() { SFSF.init('sf_a', 'sq_a'); }) });
# </script>
# <div class="iSearch">
# 	<!--新搜索20120413 begin-->
# 	<style>
# 		.soufunsearch110615rightnav .new1{ position:relative;margin-right:10px;}
# 		.soufunsearch110615rightnav .new2{width:24px;position:absolute;top:-5px;right:-13px;color:#c00;}
# 		.soufunsearch110615rightform .tr01 span {float:left;overflow:hidden;}
# 		</style>
# 	<div class="soufunsearch110615" style="margin-top:20px;margin-bottom:25px;">
# 		<div class="soufunsearch110615logo" style="margin:30px 10px 0px 8px;"><a href="http://www.3fang.com/" target="_blank" id="land_B02_01" style="height: 72px; display: block; overflow: hidden;"><img src="//js.soufunimg.com/industry/land/images/3fanglogohome.jpg"></a></div>
#
# 		<div class="soufunsearch110615right" id="landlb_B02_02">
# 			<div class="soufunsearch110615rightnav">
# 				<div class="navtd" id="_divzxm"><a href="/landfinancing/0_0_0_0_0_0_____0______1.html" target="_blank">土地转让</a></div>
# 				<div class="navtdup" id="_divzzj">招拍挂</div>
# 				<div class="navtd" id=""><a href="/itemfinancing/0_0_0_0_0_0_____0______1.html" target="_blank">项目转让</a></div>
# 				<div class="navtd" id=""><a href="/invest/_0_0_0_0_0_0_______1.html" target="_blank">求购意向</a></div>
# 				<div class="navtd" id=""><a href="/world/____0_1.html" target="_blank">海外土地</a></div>
# 				<div class="navtd"><a href="http://fdc.fang.com" target="_blank">文库报告</a></div>
# 			</div>
# 			<div class="soufunsearch110615rightform">
# 			        <input type="hidden" id="lx">
# 				        <input type="hidden" id="sf">
# 				        <input type="hidden" id="sq">
# 				        <input type="hidden" id="gh">
# 				        <input type="hidden" id="zt">
# 					    <div class="tr02 tr02-25">
#
#                             <div class="pulldowna" style="height:33px;" onclick="SFSF.bbs.menucsSF(this,'sq');" id="sf_a">
#                                 省份
#                           </div>
#                            <div class="pulldowna" style="height:33px;margin-left:5px;" onclick="SFSF.bbs.menuqxCS(this,'sf');" id="sq_a">
#                                城市
#                           </div>
#                           <div class="pulldowna" style="height:33px;margin-left:5px;" onclick="SFSF.bbs.landMenughyt(this);" id="gh_a">
#                                全部用途
#                           </div>
#                           <div class="pulldowna" style="height:33px;margin-left:5px;" onclick="SFSF.bbs.clinchADealStatusMenu(this);" id="zt_a">
#                                成交状态
#                           </div>
#                           <span id="www_299">
# 						    <input id="imgBtnSearch" type="image" src="//js.soufunimg.com/industry/land/images/fang_schh111.gif" style="width:auto;height:auto;margin-left:3px;">
# 						</span>
# 				  </div>
# 					<div class="tr01 tr01-25">
# 					    <span id="www_298">
# 						    <input maxlength="40" style="height:22px;" onclick="if(this.value==''){$('#fdj,#stx').hide();document.getElementById('q_bbs').focus();}" autocomplete="off" type="text" id="q_bbs" class="inputstyle_out" value="" onfocus="$('#fdj,#stx').hide();SFUI.toggleHint(this);" onblur="if(this.value==''){$('#fdj,#stx').show();} SFUI.toggleHint(this);" onmousemove="this.className='inputstyle_move'" onmouseout="this.className='inputstyle_out'" onkeyup="">
# 						    <span class="inpbj inpbj25" id="fdj" onclick="$('#fdj,#stx').hide();document.getElementById('q_bbs').focus();"></span>
# 						    <label id="stx" class="label25" onclick="$('#fdj,#stx').hide();">输入关键字（地块名/宗地号/位置等）</label>
# 						</span>
# 						<span class="mobile" style="margin:0px 0px 0px 10px;"><a href="/Subscribe/Mobile.aspx" target="_blank">手机订阅地块</a></span>
# 				    </div>
#
#
# 			</div>
# 		</div>
# 		<div class="industrylogo140729 fr"><img src="//js.soufunimg.com/industry/land/images/logo_zhishu.gif"></div>
# 	</div>
# 	<!--新搜索20120413 end-->
# </div>
# <script type="text/javascript" language="javascript">
#     $("#defaultHelp").unbind("mousemove").mousemove(function() {
#         var temp = this;
#         this.className = "but01 on";
#         var child = $(this).children()[1];
#         child.className = "onon";
#         $("#divHelper").show();
#         $("#helperhead").unbind("mouseleave").mouseleave(function() {
#             $("#divHelper").hide();
#             child.className = "off";
#             temp.className = "but01";
#         })
#     })
#
#     $("#MobileSearchLandA").unbind("mousemove").mousemove(function() {
#         var temp = this;
#         this.className = "ph_sd1016 ph_sd_on";
#         $("#MobileSearchLand").show();
#         $("#MobileSearchLandSpan").unbind("mouseleave").mouseleave(function() {
#             $("#MobileSearchLand").hide();
#             temp.className = "ph_sd1016";
#         })
#     })
#
#     setTimeout(function(){
#         $("#MobileSearchLand").hide();
#         $("#MobileSearchLandA").removeClass("ph_sd_on");
#     },
#     5000);
# </script>
#
# <!-- 导航 begin -->
# <style>
#     .newnav{width:960px;height:36px;line-height:36px;background:#f2f2f2;font-size:15px;}
#     .newnav .td,.newnav .tda{float:left;text-align:center; padding: 0 18px 0 18px; text-decoration:none}
#     .newnav .td.no1{ background-color:#C12225; }
#     .newnav a:hover{ color:#fff;}
#     .newnav a,.newnav a:hover{text-decoration:none}
#     .newnav .tda {background:#Ce0000;cursor:pointer; color:#fff;}
#     .newnav .tda a,.newnav .td.no1 a{ color:#fff;}
#     .newnavs {width:958px;height:28px;line-height:28px;border:1px solid #bbbbbb;background:url(//js.soufunimg.com/industry/land/images/navbj02.gif) repeat-x;text-align:center;margin-bottom:24px; color:#bbb;}
#     .newnavs a{margin-right:18px; color:#666;}
#     .newnavs em{font-style:normal;margin-right:15px;}
#     .newnavs strong{font-style:normal;margin-right:10px; color:#666;}
#     .box{width:960px;margin:0 auto;}
# </style>
# <div class="box">
# <div class="newnav" id="MenuChannelName">
#     <div class="td" style="padding:0 15px 0 20px;"><a title="土地网" id="landlb_B03_01" href="/">土地网</a></div>
#     <div class="tda sel"><a id="landlb_B03_02" href="/market/_________0_1.html" target="_blank">土地招拍挂</a></div>
#     <div class="td"><a id="landlb_B03_03" href="/landfinancing/0_0_0_0_0_0_____0______1.html" target="_blank">土地转让</a></div>
#     <div class="td"><a id="landlb_B03_04" href="/itemfinancing/0_0_0_0_0_0_____0______1.html" target="_blank">项目转让</a></div>
#     <div class="td" style="position: relative;">
#         <a id="landlb_B03_09" href="/world/____0_1.html" target="_blank">海外土地</a>
#         <span style="position: absolute; width: 29px; height: 18px; top: -5px; right: -12px;"><img src="//js.soufunimg.com/industry/land/images/nav_icon01.png" width="29" height="18"></span>
#     </div>
#     <div class="td"><a id="land_B03_23" href="http://www.tdzyw.com" target="_blank">农地流转</a></div>
#     <div class="td"><a id="landlb_B03_05" href="/LandAssessment/" target="_blank">土地评估</a></div>
#     <div class="td"><a id="landlb_B03_06" href="/report/list.aspx" target="_blank">土地报告</a></div>
#     <div class="td"><a id="landlb_B03_07" href="/data/" target="_blank">土地数据</a></div>
#     <div class="td"><a id="landlb_B03_08" href="/news/" target="_blank">土地资讯</a></div>
#
# </div>
# <div class="newnavs" style="margin-bottom:10px;">
#     <strong>找地块：</strong>
#     <a href="/landfinancing/201_0_0_0_0_0___________1.html" target="_blank" title="住宅用地转让信息" id="land_B03_10">住宅用地</a><a href="/landfinancing/202_0_0_0_0_0___________1.html" target="_blank" title="商办用地转让信息" id="land_B03_11">商办用地</a><a href="/landfinancing/203_0_0_0_0_0___________1.html" target="_blank" title="工业用地转让信息" id="land_B03_12">工业用地</a><a href="/landfinancing/204_0_0_0_0_0___________1.html" target="_blank" title="综合用地转让信息" id="land_B03_13">综合用地</a><em>|</em>
#     <strong>找项目：</strong>
#     <a href="/itemfinancing/101_0_0_0_0_0___________1.html" target="_blank" title="住宅转让信息" id="land_B03_14">住宅</a><a href="/itemfinancing/104_0_0_0_0_0___________1.html" target="_blank" title="酒店转让信息" id="land_B03_15">酒店</a><a href="/itemfinancing/105_0_0_0_0_0___________1.html" target="_blank" title="写字楼转让信息" id="land_B03_16">写字楼</a><a href="/itemfinancing/102_0_0_0_0_0___________1.html" target="_blank" title="商业转让信息" id="land_B03_17">商业</a><a href="/itemfinancing/103_0_0_0_0_0___________1.html" target="_blank" title="厂房仓库转让信息" id="land_B03_18">厂房仓库</a><em>|</em>
#     <strong>热门城市：</strong><a href="/landfinancing/0_0_0_0_0_0__110000_________1.html" target="_blank" title="北京土地/项目转让信息" id="land_B03_19">北京</a><a href="/landfinancing/0_0_0_0_0_0__310000_________1.html" target="_blank" title="上海土地/项目转让信息" id="land_B03_20">上海</a><a href="/landfinancing/0_0_0_0_0_0_5555555_440000_440100________1.html" target="_blank" title="广州土地/项目转让信息" id="land_B03_21">广州</a><a href="/landfinancing/0_0_0_0_0_0_5555555_440000_440300________1.html" target="_blank" title="深圳土地/项目转让信息" id="land_B03_22">深圳</a>
# </div>
# <!-- 导航 end -->
# </div>
# <script type="text/javascript">
#     $(document).ready(function() {
#         $("#MenuChannelName div").mousemove(function() {
#             if (this.className != "tda sel")
#                 this.className = "tda";
#         });
#         $("#MenuChannelName div").mouseleave(function() {
#             $.each($("#MenuChannelName div"), function(i, j) {
#                 if (j.className == "tda") {
#                     j.className = "td";
#                 }
#             });
#         })
#     })
# </script>
#
# <div id="wrapper">
# <div style="margin-top:10px;">
# 	<!-- AdSame ShowCode: 全网 / 招拍挂挂详情页 / 通栏 Begin -->
#
# <script type="text/javascript" src="//adapi.fang.com/release/adinfo?z=fang&amp;c=234770" charset="gbk"></script></div></div></body></html>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-efa902699590> in <module>
#      30 #             wrong.append(current_url)
#      31
# ---> 32         Info = parse_details(source)
#      33
#      34         Info['网址'] = current_url
#
# <ipython-input-8-df64518f3161> in parse_details(source)
#       4
#       5
# ----> 6     trs = html.xpath("//table[@class='tablebox02 mt10']")[0].xpath("./tbody/tr")
#       7     coordinate = html.xpath("//iframe[@id='mapframe']/@src").get()
#       8     coordinate_x = re.search(".*pointx=(\d+\.\d+)&pointy=(\d+\.\d+)", coordinate).group(1)
#
# IndexError: list index out of range

# %%
driver.quit()

# %% [markdown]
# # 函数：get_page_list得到索引页

# %%
def get_page_list(source):
    page_list = []  
    
    html = etree.HTML(source)
        
    a_href = html.xpath(".//div[@id='divAspNetPager']/a")[-2].xpath("./@href")[0]

    page_num = int(re.search("(.*_)(\d+).html", a_href).group(2))
    url_base1 = "https://land.3fang.com"
    url_base2 = re.search("(.*_)(\d+).html", a_href).group(1)
    url_base = url_base1 + url_base2

    page_list = []
    for i in range(1, page_num + 1):
        url = url_base + str(i) + ".html"
        page_list.append(url)
    return page_list

# %% [markdown]
# # 函数：parse_details爬取详细页的信息

# %%
def parse_details(source):
    html = etree.HTML(source)
    Info = {}

    
    trs = html.xpath("//table[@class='tablebox02 mt10']")[0].xpath("./tbody/tr")
    coordinate = html.xpath("//iframe[@id='mapframe']/@src").get()
    coordinate_x = re.search(".*pointx=(\d+\.\d+)&pointy=(\d+\.\d+)", coordinate).group(1)
    coordinate_y = re.search(".*pointx=(\d+\.\d+)&pointy=(\d+\.\d+)", coordinate).group(2)
    Info['经度'] = coordinate_x
    Info['维度'] = coordinate_y
    
    
    Info['地区'] = trs[0].xpath("./td[1]/a/text()")[0]
    Info['所在地'] = trs[0].xpath("./td[2]/a/text()")[0]
    Info['总面积'] = trs[1].xpath("./td[1]/em/text()")[0] + trs[1].xpath("./td[1]/text()")[0]
    Info['建设用地面积'] = trs[1].xpath("./td[2]/em/text()")[0] + trs[1].xpath("./td[2]/text()")[0]
    Info['规划建筑面积'] = trs[2].xpath("./td[1]/em/text()")[0] + trs[2].xpath("./td[1]/text()")[0]
    Info['代征面积'] = trs[2].xpath("./td[2]/em/text()")[0] 
    Info['容积率'] = trs[3].xpath("./td[1]/text()")[0]
    Info['绿化率'] = trs[3].xpath("./td[2]/text()")[0]
    Info['商业比例'] = trs[4].xpath("./td[1]/text()")[0]
    Info['建筑密度 '] = trs[4].xpath("./td[2]/text()")[0]
    Info['限制高度'] = trs[5].xpath("./td[1]/text()")[0]
    Info['出让形式'] = trs[5].xpath("./td[2]/text()")[0]
    Info['出让年限'] = trs[6].xpath("./td[1]/text()")[0]
    Info['位置'] = trs[6].xpath("./td[2]/text()")[0]
    Info['四至'] = trs[7].xpath("./td[1]/text()")[0]
    Info['规划用途'] = trs[7].xpath("./td[2]/a/text()")[0]

    trs = html.xpath("//table[@class='tablebox02 mt10']")[1].xpath("./tbody/tr")
    Info['交易状况'] = trs[0].xpath("./td[1]/text()")[0]
    Info['竞得方'] = trs[0].xpath("./td[2]/text()")[0]
    Info['起始日期'] = trs[1].xpath("./td[1]/text()")[0]
    Info['截至日期'] = trs[1].xpath("./td[2]/text()")[0]
    Info['成交日期'] = trs[2].xpath("./td[1]/text()")[0]
    Info['交易地点'] = trs[2].xpath("./td[2]/text()")[0]
    Info['起始价'] = trs[3].xpath("./td[1]/text()")[0]
    Info['成交价'] = trs[3].xpath("./td[2]/text()")[0]
    Info['楼面地价'] = trs[4].xpath("./td[1]/text()")[0]
    Info['溢价率'] = trs[4].xpath("./td[2]/text()")[0]
    Info['土地公告'] = trs[5].xpath("./td[1]/a/text()")[0]
    Info['咨询电话'] = trs[5].xpath("./td[2]/text()")[0]
    Info['保证金'] = trs[6].xpath("./td[1]/text()")[0]
    Info['最小加价幅度'] = trs[6].xpath("./td[2]/text()")[0]

    return Info
